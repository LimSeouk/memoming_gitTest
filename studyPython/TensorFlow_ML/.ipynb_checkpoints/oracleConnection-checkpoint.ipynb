# %%
from __future__ import print_function

# %%
import cx_Oracle as ora
import pandas as pd
import matplotlib.pyplot as plt

# %%
def setKoreanFont() :
    from matplotlib import font_manager, rc
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/gulim.ttc").get_name()
    rc("font", family=font_name)
    plt.rcParams["font.size"]=15
    plt.rcParams["figure.figsize"] = 14,8

# %%
# Oracle 연결 : 
con = ora.connect("WJV/wjvc3005@10.101.1.212:1521/CDW")

# %%
df_rslt = pd.read_sql("""

SELECT /*+ PARALLEL(4) FULL(A) */
       SLPART_CD 
      ,TO_DATE(ORD_DT,'YYYYMMDD') ORD_DT      
      ,COUNT(1) ORD_CNT
  FROM WJM.TW_CT_SALE_MST_MM A
 WHERE SALE_YYMM = '201906'
   AND ORD_DT BETWEEN '20190601' AND '20190630'
   AND TO_CHAR(TO_DATE(ORD_DT,'YYYYMMDD'),'dy') NOT IN('토','일')
   AND ORD_DT <> '20190606'
 GROUP BY
       SLPART_CD 
      ,ORD_DT
 ORDER BY
       SLPART_CD 
      ,ORD_DT

""", con=con)

con.close()

# %%
print(df_rslt)
# Out:
#    SLPART_CD     ORD_DT  ORD_CNT
# 0          1 2019-06-03      485
# 1          1 2019-06-04      412
# 2          1 2019-06-05     2899
# 3          1 2019-06-07      785
# 4          1 2019-06-10      969
# 5          1 2019-06-11      785
# 6          1 2019-06-12      335
# 7          1 2019-06-13      384
# 8          1 2019-06-14     1590
# 9          1 2019-06-17      316
# 10         1 2019-06-18      695
# 11         1 2019-06-19      398
# 12         1 2019-06-20      440
# 13         1 2019-06-21     1453
# 14         1 2019-06-24     1250
# 15         1 2019-06-25      790
# 16         1 2019-06-26     1096
# 17         1 2019-06-27      144
# 18         1 2019-06-28      152
# 19         2 2019-06-03    16122
# 20         2 2019-06-04     6047
# 21         2 2019-06-05     4018
# 22         2 2019-06-07     8134
# 23         2 2019-06-10     4756
# 24         2 2019-06-11     7575
# 25         2 2019-06-12     3956
# 26         2 2019-06-13     4859
# 27         2 2019-06-14    18427
# 28         2 2019-06-17     4768
# 29         2 2019-06-18     7532
# 30         2 2019-06-19     3996
# 31         2 2019-06-20     4652
# 32         2 2019-06-21    10503
# 33         2 2019-06-24     6903
# 34         2 2019-06-25     8092
# 35         2 2019-06-26    10952
# 36         2 2019-06-27     2148
# 37         2 2019-06-28     2400

# %%
setKoreanFont()
plt.plot(df_rslt[df_rslt["SLPART_CD"]=="1"]["ORD_DT"],df_rslt[df_rslt["SLPART_CD"]=="1"]["ORD_CNT"],color="BLUE")
plt.plot(df_rslt[df_rslt["SLPART_CD"]=="2"]["ORD_DT"],df_rslt[df_rslt["SLPART_CD"]=="2"]["ORD_CNT"],color="GREEN")
plt.show()

# %%
print(df_rslt["ORD_CNT"].sum())
# Out:
# 152646
